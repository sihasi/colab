# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %cd /content

# !rm -rf colab
# !git clone https://github.com/sihasi/colab.git

# %cd colab

# !uv pip install --system -r requirements-colab.txt
# !uv pip install --system -e .
# Out:
# Cloning into 'colab'...
# remote: Enumerating objects: 14, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 14 (delta 3), reused 11 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (14/14), 84.14 KiB | 7.65 MiB/s, done.
# Resolving deltas: 100% (3/3), done.
# /content/colab
# Using Python 3.12.13 environment at: /usr
# Resolved 44 packages in 6.90s
# ⠴ Preparing packages... (11/17)                                                 ^C
# Using Python 3.12.13 environment at: /usr
#   × No solution found when resolving dependencies:
#   ╰─▶ Because the current Python version (3.12.13) does not satisfy
#       Python>=3.13 and colab==0.1.0 depends on Python>=3.13, we can conclude
#       that colab==0.1.0 cannot be used.
#       And because only colab==0.1.0 is available and you require colab, we can
#       conclude that your requirements are unsatisfiable.

# %%
# Out:
# error: the argument '--system' cannot be used multiple times
#
# Usage: uv pip install [OPTIONS] <PACKAGE|--requirements <REQUIREMENTS>|--editable <EDITABLE>|--group <GROUP>>
#
# For more information, try '--help'.
