# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %cd /content

# !rm -rf colab
# !git clone https://github.com/sihasi/colab.git

# %cd colab

# !uv pip install --system -r requirements-colab.txt
# !uv pip install --system -e .
# Out:
# /content
# Cloning into 'colab'...
# remote: Enumerating objects: 28, done.
# remote: Counting objects: 100% (28/28), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 28 (delta 10), reused 25 (delta 7), pack-reused 0 (from 0)
# Receiving objects: 100% (28/28), 113.33 KiB | 6.30 MiB/s, done.
# Resolving deltas: 100% (10/10), done.
# /content/colab
# Using Python 3.12.13 environment at: /usr
# Resolved 44 packages in 160ms
# Prepared 7 packages in 6.28s
# Uninstalled 17 packages in 546ms
# Installed 17 packages in 111ms
#  - anyio==4.13.0
#  + anyio==4.14.0
#  - certifi==2026.5.20
#  + certifi==2026.6.17
#  - langchain==1.3.6
#  + langchain==1.3.10
#  - langchain-core==1.4.3
#  + langchain-core==1.4.8
#  - langchain-protocol==0.0.16
#  + langchain-protocol==0.0.18
#  - langgraph==1.2.4
#  + langgraph==1.2.6
#  - langsmith==0.8.12
#  + langsmith==0.8.18
#  - numpy==2.0.2
#  + numpy==2.4.6
#  - pandas==2.2.2
#  + pandas==3.0.3
#  - pyarrow==18.1.0
#  + pyarrow==24.0.0
#  - pydantic==2.12.3
#  + pydantic==2.13.4
#  - pydantic-core==2.41.4
#  + pydantic-core==2.46.4
#  - requests==2.32.4
#  + requests==2.34.2
#  - scikit-learn==1.6.1
#  + scikit-learn==1.9.0
#  - scipy==1.16.3
#  + scipy==1.18.0
#  - urllib3==2.5.0
#  + urllib3==2.7.0
#  - uuid-utils==0.16.0
#  + uuid-utils==0.16.2
# Using Python 3.12.13 environment at: /usr
# Resolved 45 packages in 81ms
# Prepared 1 package in 958ms
# Installed 1 package in 1msom file:///content/colab)
#  + colab-ws==0.1.0 (from file:///content/colab)
